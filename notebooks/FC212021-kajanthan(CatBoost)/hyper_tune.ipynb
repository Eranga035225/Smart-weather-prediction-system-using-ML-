# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import r2_score
import itertools
import os

# %%
# Load data
train_df = pd.read_csv("./train_test_splits/train.csv")
val_df = pd.read_csv("./train_test_splits/validate.csv")

# %%
target_cols = ['temperature', 'rainfall', 'wind_speed', 'precipitation']
feature_cols = [col for col in train_df.columns if col not in target_cols + ['date']]
cat_features = ['location_id', 'day_of_week']

# %%
train_pool = Pool(train_df[feature_cols], label=train_df[target_cols], cat_features=cat_features)
val_pool = Pool(val_df[feature_cols], label=val_df[target_cols], cat_features=cat_features)

# %%
# 2. Hyperparameter grid
learning_rates = [0.01, 0.05, 0.1]
depths         = [4, 6, 8]
l2_regs        = [1, 3, 5]              # new: regularization
iterations     = [1000]                 # fixed high value, early stopping handles exit

# %%
# 3. Tuning Loop
best_score = -np.inf
best_params = {}
results = []

# %%
for lr in learning_rates:
    for depth in depths:
        for l2 in l2_regs:
            for iter_ in iterations:
                print(f"\nTraining with lr={lr}, depth={depth}, l2_leaf_reg={l2}, iterations={iter_}")

                model = CatBoostRegressor(
                    iterations=iter_,
                    learning_rate=lr,
                    depth=depth,
                    l2_leaf_reg=l2,
                    loss_function='MultiRMSE',
                    early_stopping_rounds=50,
                    use_best_model=True,
                    verbose=100,
                    random_seed=42
                )

                model.fit(train_pool, eval_set=val_pool)

                preds = model.predict(val_df[feature_cols])
                val_true = val_df[target_cols].values

                # Compute average R² score
                r2_scores = [r2_score(val_true[:, i], preds[:, i]) for i in range(len(target_cols))]
                avg_r2 = np.mean(r2_scores)

                print(f"Avg R² Score: {avg_r2:.4f}")
                results.append({
                    "learning_rate": lr,
                    "depth": depth,
                    "l2_leaf_reg": l2,
                    "iterations": iter_,
                    "avg_r2": avg_r2
                })

                if avg_r2 > best_score:
                    best_score = avg_r2
                    best_params = {
                        "learning_rate": lr,
                        "depth": depth,
                        "l2_leaf_reg": l2,
                        "iterations": iter_
                    }
# Out:
# Training with lr=0.01, depth=4, l2_leaf_reg=1, iterations=1000
# 0:	learn: 16.4929172	test: 16.3759835	best: 16.3759835 (0)	total: 92.7ms	remaining: 1m 32s
# 100:	learn: 10.4858339	test: 10.6033855	best: 10.6033855 (100)	total: 8.34s	remaining: 1m 14s
# 200:	learn: 8.2801859	test: 8.8096123	best: 8.8096123 (200)	total: 18.2s	remaining: 1m 12s
# 300:	learn: 7.3883117	test: 8.2340490	best: 8.2340490 (300)	total: 29.8s	remaining: 1m 9s
# 400:	learn: 6.9642090	test: 8.0007105	best: 8.0007105 (400)	total: 41.6s	remaining: 1m 2s
# 500:	learn: 6.7306082	test: 7.8857029	best: 7.8857029 (500)	total: 53.2s	remaining: 52.9s
# 600:	learn: 6.5796876	test: 7.8056943	best: 7.8056943 (600)	total: 1m 4s	remaining: 42.8s
# 700:	learn: 6.4760429	test: 7.7370360	best: 7.7370360 (700)	total: 1m 15s	remaining: 32.2s
# 800:	learn: 6.3949198	test: 7.6845654	best: 7.6845654 (800)	total: 1m 27s	remaining: 21.7s
# 900:	learn: 6.3308681	test: 7.6486478	best: 7.6486478 (900)	total: 1m 38s	remaining: 10.8s
# 999:	learn: 6.2742313	test: 7.6148219	best: 7.6148219 (999)	total: 1m 50s	remaining: 0us
#
# bestTest = 7.614821908
# bestIteration = 999
#
# Avg R² Score: 0.8409
#
# Training with lr=0.01, depth=4, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.4933186	test: 16.3763507	best: 16.3763507 (0)	total: 144ms	remaining: 2m 23s
# 100:	learn: 10.4974857	test: 10.6103267	best: 10.6103267 (100)	total: 11.3s	remaining: 1m 40s
# 200:	learn: 8.2901792	test: 8.8103642	best: 8.8103642 (200)	total: 22.8s	remaining: 1m 30s
# 300:	learn: 7.4037317	test: 8.2280264	best: 8.2280264 (300)	total: 33.5s	remaining: 1m 17s
# 400:	learn: 6.9809487	test: 8.0032855	best: 8.0032855 (400)	total: 44.8s	remaining: 1m 6s
# 500:	learn: 6.7487151	test: 7.8852613	best: 7.8852613 (500)	total: 56.3s	remaining: 56.1s
# 600:	learn: 6.5968548	test: 7.8077951	best: 7.8077951 (600)	total: 1m 7s	remaining: 44.6s
# 700:	learn: 6.4976899	test: 7.7433636	best: 7.7433636 (700)	total: 1m 18s	remaining: 33.4s
# 800:	learn: 6.4236380	test: 7.6926627	best: 7.6926627 (800)	total: 1m 29s	remaining: 22.3s
# 900:	learn: 6.3575488	test: 7.6564868	best: 7.6562694 (897)	total: 1m 40s	remaining: 11s
# 999:	learn: 6.3039821	test: 7.6271435	best: 7.6271435 (999)	total: 1m 52s	remaining: 0us
#
# bestTest = 7.627143545
# bestIteration = 999
#
# Avg R² Score: 0.8400
#
# Training with lr=0.01, depth=4, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.4937132	test: 16.3767116	best: 16.3767116 (0)	total: 105ms	remaining: 1m 44s
# 100:	learn: 10.5121222	test: 10.6142691	best: 10.6142691 (100)	total: 11s	remaining: 1m 38s
# 200:	learn: 8.2984362	test: 8.8062963	best: 8.8062963 (200)	total: 22.9s	remaining: 1m 31s
# 300:	learn: 7.4180400	test: 8.2369011	best: 8.2369011 (300)	total: 34.4s	remaining: 1m 19s
# 400:	learn: 7.0000252	test: 8.0088509	best: 8.0088509 (400)	total: 45.3s	remaining: 1m 7s
# 500:	learn: 6.7650985	test: 7.8917670	best: 7.8917670 (500)	total: 56.7s	remaining: 56.5s
# 600:	learn: 6.6193682	test: 7.8148931	best: 7.8148931 (600)	total: 1m 7s	remaining: 44.9s
# 700:	learn: 6.5111444	test: 7.7548339	best: 7.7548339 (700)	total: 1m 18s	remaining: 33.3s
# 800:	learn: 6.4327157	test: 7.7023720	best: 7.7023720 (800)	total: 1m 30s	remaining: 22.5s
# 900:	learn: 6.3739205	test: 7.6652376	best: 7.6652376 (900)	total: 1m 42s	remaining: 11.3s
# 999:	learn: 6.3192283	test: 7.6295305	best: 7.6294833 (998)	total: 1m 53s	remaining: 0us
#
# bestTest = 7.62948331
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Avg R² Score: 0.8399
#
# Training with lr=0.01, depth=6, l2_leaf_reg=1, iterations=1000
# 0:	learn: 16.4789020	test: 16.3612473	best: 16.3612473 (0)	total: 154ms	remaining: 2m 33s
# 100:	learn: 9.6811373	test: 9.9430476	best: 9.9430476 (100)	total: 17.2s	remaining: 2m 33s
# 200:	learn: 7.5727015	test: 8.3824149	best: 8.3824149 (200)	total: 34.3s	remaining: 2m 16s
# 300:	learn: 6.8058506	test: 7.9554434	best: 7.9554434 (300)	total: 52s	remaining: 2m
# 400:	learn: 6.4659759	test: 7.7885422	best: 7.7885422 (400)	total: 1m 8s	remaining: 1m 42s
# 500:	learn: 6.2773100	test: 7.6855090	best: 7.6855090 (500)	total: 1m 27s	remaining: 1m 27s
# 600:	learn: 6.1511759	test: 7.6087667	best: 7.6087667 (600)	total: 1m 45s	remaining: 1m 9s
# 700:	learn: 6.0483528	test: 7.5651652	best: 7.5651652 (700)	total: 2m 3s	remaining: 52.7s
# 800:	learn: 5.9643443	test: 7.5295444	best: 7.5295444 (800)	total: 2m 22s	remaining: 35.4s
# 900:	learn: 5.8794499	test: 7.5017012	best: 7.5017012 (900)	total: 2m 39s	remaining: 17.6s
# 999:	learn: 5.8028509	test: 7.4822326	best: 7.4822326 (999)	total: 2m 57s	remaining: 0us
#
# bestTest = 7.482232559
# bestIteration = 999
#
# Avg R² Score: 0.8511
#
# Training with lr=0.01, depth=6, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.4800297	test: 16.3623306	best: 16.3623306 (0)	total: 180ms	remaining: 2m 59s
# 100:	learn: 9.7152984	test: 9.9713841	best: 9.9713841 (100)	total: 17.2s	remaining: 2m 33s
# 200:	learn: 7.6039097	test: 8.4197505	best: 8.4197505 (200)	total: 34.5s	remaining: 2m 17s
# 300:	learn: 6.8459130	test: 7.9829484	best: 7.9829484 (300)	total: 52.7s	remaining: 2m 2s
# 400:	learn: 6.5032832	test: 7.8137420	best: 7.8137420 (400)	total: 1m 10s	remaining: 1m 44s
# 500:	learn: 6.3173895	test: 7.7161250	best: 7.7160235 (499)	total: 1m 28s	remaining: 1m 27s
# 600:	learn: 6.1856216	test: 7.6408362	best: 7.6408362 (600)	total: 1m 45s	remaining: 1m 10s
# 700:	learn: 6.0819515	test: 7.5885455	best: 7.5885455 (700)	total: 2m 2s	remaining: 52.4s
# 800:	learn: 6.0019684	test: 7.5484582	best: 7.5484582 (800)	total: 2m 20s	remaining: 34.9s
# 900:	learn: 5.9319944	test: 7.5237104	best: 7.5235264 (895)	total: 2m 38s	remaining: 17.4s
# 999:	learn: 5.8652517	test: 7.5030687	best: 7.5028762 (991)	total: 2m 56s	remaining: 0us
#
# bestTest = 7.502876239
# bestIteration = 991
#
# Shrink model to first 992 iterations.
# Avg R² Score: 0.8499
#
# Training with lr=0.01, depth=6, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.4810722	test: 16.3633496	best: 16.3633496 (0)	total: 209ms	remaining: 3m 29s
# 100:	learn: 9.7481515	test: 9.9885474	best: 9.9885474 (100)	total: 18.3s	remaining: 2m 42s
# 200:	learn: 7.6309927	test: 8.4319216	best: 8.4319216 (200)	total: 35.8s	remaining: 2m 22s
# 300:	learn: 6.8607957	test: 7.9829607	best: 7.9829607 (300)	total: 54.2s	remaining: 2m 5s
# 400:	learn: 6.5197639	test: 7.8178060	best: 7.8178060 (400)	total: 1m 13s	remaining: 1m 49s
# 500:	learn: 6.3355514	test: 7.7220493	best: 7.7220493 (500)	total: 1m 36s	remaining: 1m 35s
# 600:	learn: 6.2061822	test: 7.6426699	best: 7.6426699 (600)	total: 1m 59s	remaining: 1m 19s
# 700:	learn: 6.1095804	test: 7.5873425	best: 7.5873425 (700)	total: 2m 23s	remaining: 1m 1s
# 800:	learn: 6.0311163	test: 7.5477412	best: 7.5477412 (800)	total: 2m 46s	remaining: 41.3s
# 900:	learn: 5.9594455	test: 7.5199241	best: 7.5197681 (899)	total: 3m 8s	remaining: 20.8s
# 999:	learn: 5.8948436	test: 7.4997549	best: 7.4996788 (998)	total: 3m 31s	remaining: 0us
#
# bestTest = 7.499678784
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Avg R² Score: 0.8501
#
# Training with lr=0.01, depth=8, l2_leaf_reg=1, iterations=1000
# 0:	learn: 16.4737036	test: 16.3568330	best: 16.3568330 (0)	total: 428ms	remaining: 7m 7s
# 100:	learn: 9.2987964	test: 9.7937362	best: 9.7937362 (100)	total: 35.1s	remaining: 5m 12s
# 200:	learn: 7.1073213	test: 8.2699989	best: 8.2699989 (200)	total: 1m 4s	remaining: 4m 15s
# 300:	learn: 6.3724952	test: 7.8639263	best: 7.8639263 (300)	total: 1m 35s	remaining: 3m 42s
# 400:	learn: 6.0443844	test: 7.6918793	best: 7.6918793 (400)	total: 2m 13s	remaining: 3m 19s
# 500:	learn: 5.8330551	test: 7.5951899	best: 7.5951899 (500)	total: 2m 52s	remaining: 2m 52s
# 600:	learn: 5.6859205	test: 7.5308298	best: 7.5305715 (599)	total: 3m 30s	remaining: 2m 19s
# 700:	learn: 5.5670610	test: 7.4897708	best: 7.4897708 (700)	total: 4m 5s	remaining: 1m 44s
# 800:	learn: 5.4540089	test: 7.4573153	best: 7.4572562 (799)	total: 4m 36s	remaining: 1m 8s
# 900:	learn: 5.3503503	test: 7.4360000	best: 7.4360000 (900)	total: 5m 5s	remaining: 33.6s
# 999:	learn: 5.2589156	test: 7.4205580	best: 7.4205580 (999)	total: 5m 33s	remaining: 0us
#
# bestTest = 7.420558021
# bestIteration = 999
#
# Avg R² Score: 0.8560
#
# Training with lr=0.01, depth=8, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.4753110	test: 16.3583876	best: 16.3583876 (0)	total: 241ms	remaining: 4m
# 100:	learn: 9.3940898	test: 9.8636325	best: 9.8636325 (100)	total: 29s	remaining: 4m 17s
# 200:	learn: 7.1874676	test: 8.3206892	best: 8.3206892 (200)	total: 1m	remaining: 3m 59s
# 300:	learn: 6.4450761	test: 7.9200088	best: 7.9200088 (300)	total: 1m 51s	remaining: 4m 19s
# 400:	learn: 6.1162660	test: 7.7625810	best: 7.7625810 (400)	total: 2m 48s	remaining: 4m 12s
# 500:	learn: 5.9159928	test: 7.6572917	best: 7.6572917 (500)	total: 3m 45s	remaining: 3m 44s
# 600:	learn: 5.7824197	test: 7.5892637	best: 7.5892637 (600)	total: 4m 43s	remaining: 3m 7s
# 700:	learn: 5.6689356	test: 7.5500848	best: 7.5499578 (699)	total: 5m 40s	remaining: 2m 25s
# 800:	learn: 5.5697188	test: 7.5231310	best: 7.5229959 (797)	total: 6m 38s	remaining: 1m 38s
# 900:	learn: 5.4812383	test: 7.4984306	best: 7.4982263 (897)	total: 7m 36s	remaining: 50.2s
# 999:	learn: 5.3964123	test: 7.4822399	best: 7.4816970 (998)	total: 8m 13s	remaining: 0us
#
# bestTest = 7.481696975
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Avg R² Score: 0.8532
#
# Training with lr=0.01, depth=8, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.4767287	test: 16.3597776	best: 16.3597776 (0)	total: 355ms	remaining: 5m 54s
# 100:	learn: 9.4674559	test: 9.9183560	best: 9.9183560 (100)	total: 37.6s	remaining: 5m 34s
# 200:	learn: 7.2556072	test: 8.3663969	best: 8.3663969 (200)	total: 1m 15s	remaining: 5m 1s
# 300:	learn: 6.5013410	test: 7.9539029	best: 7.9539029 (300)	total: 1m 53s	remaining: 4m 23s
# 400:	learn: 6.1649876	test: 7.7891399	best: 7.7891399 (400)	total: 2m 29s	remaining: 3m 43s
# 500:	learn: 5.9692736	test: 7.6908332	best: 7.6908332 (500)	total: 3m 24s	remaining: 3m 23s
# 600:	learn: 5.8344964	test: 7.6267128	best: 7.6267128 (600)	total: 4m 11s	remaining: 2m 47s
# 700:	learn: 5.7248369	test: 7.5884537	best: 7.5884537 (700)	total: 4m 58s	remaining: 2m 7s
# 800:	learn: 5.6396010	test: 7.5584718	best: 7.5584718 (800)	total: 5m 47s	remaining: 1m 26s
# 900:	learn: 5.5601595	test: 7.5376235	best: 7.5371502 (898)	total: 6m 53s	remaining: 45.4s
# 999:	learn: 5.4808826	test: 7.5234646	best: 7.5234417 (998)	total: 7m 58s	remaining: 0us
#
# bestTest = 7.523441663
# bestIteration = 998
#
# Shrink model to first 999 iterations.
# Avg R² Score: 0.8514
#
# Training with lr=0.05, depth=4, l2_leaf_reg=1, iterations=1000
# 0:	learn: 16.0909097	test: 15.9815332	best: 15.9815332 (0)	total: 238ms	remaining: 3m 57s
# 100:	learn: 6.7252253	test: 7.8630324	best: 7.8630324 (100)	total: 22.1s	remaining: 3m 17s
# 200:	learn: 6.2928002	test: 7.5977454	best: 7.5977454 (200)	total: 43.9s	remaining: 2m 54s
# 300:	learn: 6.0523078	test: 7.4987509	best: 7.4986432 (299)	total: 1m 5s	remaining: 2m 31s
# 400:	learn: 5.8763460	test: 7.4744107	best: 7.4739518 (397)	total: 1m 27s	remaining: 2m 10s
# 500:	learn: 5.7362393	test: 7.4510912	best: 7.4484833 (498)	total: 1m 49s	remaining: 1m 48s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.448483327
# bestIteration = 498
#
# Shrink model to first 499 iterations.
# Avg R² Score: 0.8540
#
# Training with lr=0.05, depth=4, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.0928843	test: 15.9833369	best: 15.9833369 (0)	total: 243ms	remaining: 4m 3s
# 100:	learn: 6.7355960	test: 7.8709605	best: 7.8709605 (100)	total: 22s	remaining: 3m 15s
# 200:	learn: 6.3074264	test: 7.6125082	best: 7.6125082 (200)	total: 43.6s	remaining: 2m 53s
# 300:	learn: 6.0938502	test: 7.5122079	best: 7.5122079 (300)	total: 1m 5s	remaining: 2m 32s
# 400:	learn: 5.9328954	test: 7.4590387	best: 7.4590387 (400)	total: 1m 27s	remaining: 2m 10s
# 500:	learn: 5.8068131	test: 7.4430740	best: 7.4409819 (478)	total: 1m 49s	remaining: 1m 48s
# 600:	learn: 5.6994940	test: 7.4182103	best: 7.4161020 (598)	total: 2m 10s	remaining: 1m 26s
# 700:	learn: 5.6163907	test: 7.4179912	best: 7.4061448 (658)	total: 2m 32s	remaining: 1m 5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.40614476
# bestIteration = 658
#
# Shrink model to first 659 iterations.
# Avg R² Score: 0.8566
#
# Training with lr=0.05, depth=4, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.0948258	test: 15.9851103	best: 15.9851103 (0)	total: 213ms	remaining: 3m 32s
# 100:	learn: 6.7471079	test: 7.8975334	best: 7.8975334 (100)	total: 22s	remaining: 3m 15s
# 200:	learn: 6.3036293	test: 7.6199494	best: 7.6192751 (198)	total: 43.8s	remaining: 2m 54s
# 300:	learn: 6.1003139	test: 7.5300626	best: 7.5295892 (299)	total: 1m 5s	remaining: 2m 32s
# 400:	learn: 5.9540434	test: 7.4832408	best: 7.4822180 (398)	total: 1m 27s	remaining: 2m 10s
# 500:	learn: 5.8352416	test: 7.4576815	best: 7.4558144 (491)	total: 1m 49s	remaining: 1m 48s
# 600:	learn: 5.7357796	test: 7.4417655	best: 7.4417655 (600)	total: 2m 11s	remaining: 1m 27s
# 700:	learn: 5.6541281	test: 7.4259072	best: 7.4259072 (700)	total: 2m 33s	remaining: 1m 5s
# 800:	learn: 5.5781157	test: 7.4182206	best: 7.4150684 (789)	total: 2m 55s	remaining: 43.6s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.415068376
# bestIteration = 789
#
# Shrink model to first 790 iterations.
# Avg R² Score: 0.8568
#
# Training with lr=0.05, depth=6, l2_leaf_reg=1, iterations=1000
# 0:	learn: 16.0203611	test: 15.9075077	best: 15.9075077 (0)	total: 178ms	remaining: 2m 57s
# 100:	learn: 6.2695414	test: 7.7119357	best: 7.7098337 (99)	total: 18.1s	remaining: 2m 40s
# 200:	learn: 5.7843527	test: 7.5154271	best: 7.5154271 (200)	total: 39.7s	remaining: 2m 37s
# 300:	learn: 5.4819927	test: 7.4687750	best: 7.4671839 (299)	total: 1m	remaining: 2m 19s
# 400:	learn: 5.2478806	test: 7.4334533	best: 7.4305383 (388)	total: 1m 19s	remaining: 1m 59s
# 500:	learn: 5.0603153	test: 7.4247315	best: 7.4214375 (496)	total: 1m 39s	remaining: 1m 39s
# 600:	learn: 4.9085368	test: 7.4128453	best: 7.4118451 (557)	total: 1m 59s	remaining: 1m 19s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.411845091
# bestIteration = 557
#
# Shrink model to first 558 iterations.
# Avg R² Score: 0.8587
#
# Training with lr=0.05, depth=6, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.0259364	test: 15.9128441	best: 15.9128441 (0)	total: 180ms	remaining: 2m 59s
# 100:	learn: 6.3096475	test: 7.7027277	best: 7.7027277 (100)	total: 19.4s	remaining: 2m 52s
# 200:	learn: 5.8524860	test: 7.4924010	best: 7.4921783 (192)	total: 38.8s	remaining: 2m 34s
# 300:	learn: 5.5746640	test: 7.4584529	best: 7.4580966 (295)	total: 58s	remaining: 2m 14s
# 400:	learn: 5.3668439	test: 7.4358144	best: 7.4314321 (394)	total: 1m 17s	remaining: 1m 55s
# 500:	learn: 5.1891252	test: 7.4289595	best: 7.4216783 (487)	total: 1m 36s	remaining: 1m 36s
# 600:	learn: 5.0433017	test: 7.4162992	best: 7.4078057 (584)	total: 1m 56s	remaining: 1m 17s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.407805734
# bestIteration = 584
#
# Shrink model to first 585 iterations.
# Avg R² Score: 0.8586
#
# Training with lr=0.05, depth=6, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.0310943	test: 15.9178701	best: 15.9178701 (0)	total: 173ms	remaining: 2m 53s
# 100:	learn: 6.3442584	test: 7.7274547	best: 7.7274547 (100)	total: 19.4s	remaining: 2m 52s
# 200:	learn: 5.9032943	test: 7.5400010	best: 7.5400010 (200)	total: 39.1s	remaining: 2m 35s
# 300:	learn: 5.6592787	test: 7.4886539	best: 7.4886539 (300)	total: 1m 3s	remaining: 2m 27s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.482509828
# bestIteration = 305
#
# Shrink model to first 306 iterations.
# Avg R² Score: 0.8523
#
# Training with lr=0.05, depth=8, l2_leaf_reg=1, iterations=1000
# 0:	learn: 15.9941157	test: 15.8852665	best: 15.8852665 (0)	total: 526ms	remaining: 8m 45s
# 100:	learn: 5.8337368	test: 7.6702929	best: 7.6702929 (100)	total: 43.6s	remaining: 6m 28s
# 200:	learn: 5.2590828	test: 7.5033533	best: 7.5003770 (184)	total: 1m 26s	remaining: 5m 43s
# 300:	learn: 4.8568428	test: 7.4580334	best: 7.4580334 (300)	total: 2m 9s	remaining: 4m 59s
# 400:	learn: 4.5667433	test: 7.4201990	best: 7.4193022 (379)	total: 2m 52s	remaining: 4m 17s
# 500:	learn: 4.3474660	test: 7.4166884	best: 7.4149654 (489)	total: 3m 35s	remaining: 3m 34s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.414965356
# bestIteration = 489
#
# Shrink model to first 490 iterations.
# Avg R² Score: 0.8599
#
# Training with lr=0.05, depth=8, l2_leaf_reg=3, iterations=1000
# 0:	learn: 16.0020830	test: 15.8929429	best: 15.8929429 (0)	total: 449ms	remaining: 7m 28s
# 100:	learn: 5.9587373	test: 7.6922266	best: 7.6922266 (100)	total: 43.2s	remaining: 6m 24s
# 200:	learn: 5.4145550	test: 7.5212487	best: 7.5193678 (198)	total: 1m 25s	remaining: 5m 41s
# 300:	learn: 5.0671947	test: 7.4844793	best: 7.4804789 (285)	total: 2m 9s	remaining: 4m 59s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.480478901
# bestIteration = 285
#
# Shrink model to first 286 iterations.
# Avg R² Score: 0.8550
#
# Training with lr=0.05, depth=8, l2_leaf_reg=5, iterations=1000
# 0:	learn: 16.0091156	test: 15.8998192	best: 15.8998192 (0)	total: 430ms	remaining: 7m 9s
# 100:	learn: 5.9870444	test: 7.7070311	best: 7.7070311 (100)	total: 42.8s	remaining: 6m 21s
# 200:	learn: 5.4743089	test: 7.5291515	best: 7.5291515 (200)	total: 1m 16s	remaining: 5m 4s
# 300:	learn: 5.1538082	test: 7.4919104	best: 7.4916563 (299)	total: 1m 58s	remaining: 4m 34s
# 400:	learn: 4.9160089	test: 7.4934139	best: 7.4884838 (378)	total: 2m 55s	remaining: 4m 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.488483768
# bestIteration = 378
#
# Shrink model to first 379 iterations.
# Avg R² Score: 0.8554
#
# Training with lr=0.1, depth=4, l2_leaf_reg=1, iterations=1000
# 0:	learn: 15.5981323	test: 15.4995696	best: 15.4995696 (0)	total: 220ms	remaining: 3m 39s
# 100:	learn: 6.2871767	test: 7.6793060	best: 7.6793060 (100)	total: 22s	remaining: 3m 15s
# 200:	learn: 5.8912947	test: 7.5485862	best: 7.5455476 (193)	total: 43.9s	remaining: 2m 54s
# 300:	learn: 5.6637632	test: 7.5072718	best: 7.5040684 (297)	total: 1m 5s	remaining: 2m 32s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.502435612
# bestIteration = 343
#
# Shrink model to first 344 iterations.
# Avg R² Score: 0.8530
#
# Training with lr=0.1, depth=4, l2_leaf_reg=3, iterations=1000
# 0:	learn: 15.6019937	test: 15.5030897	best: 15.5030897 (0)	total: 308ms	remaining: 5m 7s
# 100:	learn: 6.3386606	test: 7.6842341	best: 7.6842341 (100)	total: 22.9s	remaining: 3m 23s
# 200:	learn: 5.9803191	test: 7.5597379	best: 7.5580486 (196)	total: 34s	remaining: 2m 15s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.558048593
# bestIteration = 196
#
# Shrink model to first 197 iterations.
# Avg R² Score: 0.8483
#
# Training with lr=0.1, depth=4, l2_leaf_reg=5, iterations=1000
# 0:	learn: 15.6057915	test: 15.5065518	best: 15.5065518 (0)	total: 109ms	remaining: 1m 49s
# 100:	learn: 6.3579108	test: 7.6610000	best: 7.6610000 (100)	total: 12.3s	remaining: 1m 49s
# 200:	learn: 6.0106916	test: 7.5187605	best: 7.5187605 (200)	total: 26.8s	remaining: 1m 46s
# 300:	learn: 5.7804338	test: 7.4864222	best: 7.4780243 (285)	total: 45.6s	remaining: 1m 45s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.478024252
# bestIteration = 285
#
# Shrink model to first 286 iterations.
# Avg R² Score: 0.8526
#
# Training with lr=0.1, depth=6, l2_leaf_reg=1, iterations=1000
# 0:	learn: 15.4558655	test: 15.3507081	best: 15.3507081 (0)	total: 326ms	remaining: 5m 25s
# 100:	learn: 5.8297784	test: 7.5605967	best: 7.5605967 (100)	total: 34s	remaining: 5m 2s
# 200:	learn: 5.2771235	test: 7.4734709	best: 7.4722598 (195)	total: 1m 7s	remaining: 4m 28s
# 300:	learn: 4.9328970	test: 7.4219893	best: 7.4215555 (294)	total: 1m 41s	remaining: 3m 56s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.420537063
# bestIteration = 301
#
# Shrink model to first 302 iterations.
# Avg R² Score: 0.8581
#
# Training with lr=0.1, depth=6, l2_leaf_reg=3, iterations=1000
# 0:	learn: 15.4668413	test: 15.3611598	best: 15.3611598 (0)	total: 168ms	remaining: 2m 48s
# 100:	learn: 5.8966895	test: 7.5364051	best: 7.5364051 (100)	total: 19.4s	remaining: 2m 52s
# 200:	learn: 5.3934183	test: 7.4548345	best: 7.4456991 (197)	total: 41s	remaining: 2m 43s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.429384772
# bestIteration = 239
#
# Shrink model to first 240 iterations.
# Avg R² Score: 0.8566
#
# Training with lr=0.1, depth=6, l2_leaf_reg=5, iterations=1000
# 0:	learn: 15.4770057	test: 15.3710214	best: 15.3710214 (0)	total: 182ms	remaining: 3m 1s
# 100:	learn: 5.9015887	test: 7.5561708	best: 7.5387717 (86)	total: 22s	remaining: 3m 15s
# 200:	learn: 5.4765116	test: 7.4800679	best: 7.4800679 (200)	total: 50.9s	remaining: 3m 22s
# 300:	learn: 5.1916715	test: 7.4513392	best: 7.4482051 (269)	total: 1m 23s	remaining: 3m 13s
# 400:	learn: 4.9517661	test: 7.4234120	best: 7.4234120 (400)	total: 1m 54s	remaining: 2m 51s
# 500:	learn: 4.7653477	test: 7.4139898	best: 7.4039977 (482)	total: 2m 26s	remaining: 2m 25s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.40399765
# bestIteration = 482
#
# Shrink model to first 483 iterations.
# Avg R² Score: 0.8597
#
# Training with lr=0.1, depth=8, l2_leaf_reg=1, iterations=1000
# 0:	learn: 15.4027262	test: 15.3058032	best: 15.3058032 (0)	total: 534ms	remaining: 8m 53s
# 100:	learn: 5.2761846	test: 7.4656851	best: 7.4614953 (99)	total: 41.4s	remaining: 6m 8s
# 200:	learn: 4.5589695	test: 7.3748053	best: 7.3748041 (199)	total: 1m 16s	remaining: 5m 4s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.353634255
# bestIteration = 246
#
# Shrink model to first 247 iterations.
# Avg R² Score: 0.8611
#
# Training with lr=0.1, depth=8, l2_leaf_reg=3, iterations=1000
# 0:	learn: 15.4184658	test: 15.3208872	best: 15.3208872 (0)	total: 401ms	remaining: 6m 40s
# 100:	learn: 5.3977427	test: 7.4593984	best: 7.4569115 (83)	total: 45.4s	remaining: 6m 44s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.409050563
# bestIteration = 142
#
# Shrink model to first 143 iterations.
# Avg R² Score: 0.8568
#
# Training with lr=0.1, depth=8, l2_leaf_reg=5, iterations=1000
# 0:	learn: 15.4323751	test: 15.3344344	best: 15.3344344 (0)	total: 579ms	remaining: 9m 38s
# 100:	learn: 5.4669879	test: 7.5739271	best: 7.5653907 (91)	total: 56.1s	remaining: 8m 19s
# 200:	learn: 4.9228396	test: 7.5135977	best: 7.5097153 (191)	total: 1m 53s	remaining: 7m 32s
# 300:	learn: 4.5258184	test: 7.4950240	best: 7.4926338 (299)	total: 2m 34s	remaining: 5m 57s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 7.492633849
# bestIteration = 299
#
# Shrink model to first 300 iterations.
# Avg R² Score: 0.8566

# %%
# 4. Save tuning results
results_df = pd.DataFrame(results)
os.makedirs("tuning_logs", exist_ok=True)
results_df.to_csv("tuning_logs/hyperparameter_tuning_log.csv", index=False)

# 5. Output best result
print("\nBest Hyperparameters Found:")
print(best_params)
print(f"Best Avg R² Score: {best_score:.4f}")
# Out:
# Best Hyperparameters Found:
# {'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'iterations': 1000}
# Best Avg R² Score: 0.8611
