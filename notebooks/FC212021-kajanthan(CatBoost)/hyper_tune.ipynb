# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import itertools
import os

# %%
# Load data
train_df = pd.read_csv("train_test_splits/train.csv", parse_dates=['date'])
val_df   = pd.read_csv("train_test_splits/validate.csv", parse_dates=['date'])

# %%
train_df.head()
# Out:
#    location_id       date  weather_code (wmo code)  temperature_2m_max (°C)  \
# 0            0 2010-01-08                       53                     28.4
# 1            0 2010-01-09                       61                     29.1
# 2            0 2010-01-10                       51                     30.1
# 3            0 2010-01-11                       51                     29.7
# 4            0 2010-01-12                       63                     29.8
#
#    temperature_2m_min (°C)  temperature  apparent_temperature_max (°C)  \
# 0                     23.4         25.6                           32.2
# 1                     23.5         26.0                           35.4
# 2                     22.6         26.2                           35.8
# 3                     22.4         26.3                           35.5
# 4                     24.2         26.3                           36.7
#
#    apparent_temperature_min (°C)  apparent_temperature_mean (°C)  \
# ...

# %%
target_cols = ['temperature', 'rainfall', 'wind_speed', 'precipitation']
feature_cols = [col for col in train_df.columns if col not in target_cols + ['date']]
cat_features = ['location_id', 'day_of_week']

# %%
train_pool = Pool(train_df[feature_cols], label=train_df[target_cols], cat_features=cat_features)
val_pool = Pool(val_df[feature_cols], label=val_df[target_cols], cat_features=cat_features)

# %%
# Step 3: Define grid of hyperparameters
param_grid = {
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.03, 0.05],
    'l2_leaf_reg': [1, 3, 5],
    'iterations': [500, 1000]
}

# %%
# Create all combinations
grid = list(itertools.product(
    param_grid['depth'],
    param_grid['learning_rate'],
    param_grid['l2_leaf_reg'],
    param_grid['iterations']
))

# %%
# Step 2: Loop through each combination and evaluate
best_score = float("inf")
best_params = None

print(f"Starting manual hyperparameter tuning ({len(grid)} combinations)...\n")

for depth, lr, l2, iters in grid:
    model = CatBoostRegressor(
        depth=depth,
        learning_rate=lr,
        l2_leaf_reg=l2,
        iterations=iters,
        loss_function='MultiRMSE',
        random_seed=42,
        verbose=0
    )
    
    # Train on training data
    model.fit(train_pool)
    
    # Predict on validation set
    preds = model.predict(val_pool)
    
    # Compute overall RMSE across all targets
    rmse_list = []
    for i, target in enumerate(target_cols):
        y_true = val_df[target]
        y_pred = preds[:, i]
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        rmse_list.append(rmse)
    
    avg_rmse = np.mean(rmse_list)
    
    print(f"Params: depth={depth}, lr={lr}, l2={l2}, iter={iters} -> Avg RMSE: {avg_rmse:.4f}")
    
    # Update best
    if avg_rmse < best_score:
        best_score = avg_rmse
        best_params = {'depth': depth, 'learning_rate': lr, 'l2_leaf_reg': l2, 'iterations': iters}
# Out:
# Starting manual hyperparameter tuning (54 combinations)...
#
# Params: depth=4, lr=0.01, l2=1, iter=500 -> Avg RMSE: 3.6630
# Params: depth=4, lr=0.01, l2=1, iter=1000 -> Avg RMSE: 3.5052
# Params: depth=4, lr=0.01, l2=3, iter=500 -> Avg RMSE: 3.6690
# Params: depth=4, lr=0.01, l2=3, iter=1000 -> Avg RMSE: 3.5085
# Params: depth=4, lr=0.01, l2=5, iter=500 -> Avg RMSE: 3.6730
# Params: depth=4, lr=0.01, l2=5, iter=1000 -> Avg RMSE: 3.5120
# Params: depth=4, lr=0.03, l2=1, iter=500 -> Avg RMSE: 3.4618
# Params: depth=4, lr=0.03, l2=1, iter=1000 -> Avg RMSE: 3.4024
# Params: depth=4, lr=0.03, l2=3, iter=500 -> Avg RMSE: 3.4611
# Params: depth=4, lr=0.03, l2=3, iter=1000 -> Avg RMSE: 3.4008
# Params: depth=4, lr=0.03, l2=5, iter=500 -> Avg RMSE: 3.4552
# Params: depth=4, lr=0.03, l2=5, iter=1000 -> Avg RMSE: 3.4016
# Params: depth=4, lr=0.05, l2=1, iter=500 -> Avg RMSE: 3.4091
# Params: depth=4, lr=0.05, l2=1, iter=1000 -> Avg RMSE: 3.3632
# ...

# %%
# Step 3: Train final model with best params
print("\nBest Hyperparameters:", best_params)
model = CatBoostRegressor(
    **best_params,
    loss_function='MultiRMSE',
    random_seed=42,
    verbose=100
)
model.fit(train_pool)
# Out:
# Best Hyperparameters: {'depth': 8, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 1000}
# 0:	learn: 15.9960176	total: 284ms	remaining: 4m 43s
# 100:	learn: 6.3150847	total: 29.5s	remaining: 4m 22s
# 200:	learn: 5.7694730	total: 59.1s	remaining: 3m 55s
# 300:	learn: 5.3736718	total: 1m 28s	remaining: 3m 24s
# 400:	learn: 5.0625253	total: 1m 57s	remaining: 2m 55s
# 500:	learn: 4.8030194	total: 2m 28s	remaining: 2m 27s
# 600:	learn: 4.6166756	total: 2m 57s	remaining: 1m 58s
# 700:	learn: 4.4487074	total: 3m 27s	remaining: 1m 28s
# 800:	learn: 4.2882756	total: 3m 57s	remaining: 58.9s
# 900:	learn: 4.1566672	total: 4m 26s	remaining: 29.3s
# 999:	learn: 4.0389436	total: 4m 56s	remaining: 0us

# %%
# Step 4: Save tuned model
os.makedirs("models", exist_ok=True)
tuned_model_path = "../../models/catboost_model_final.cbm"
model.save_model(tuned_model_path)
print(f"Trained tuned model saved to: {tuned_model_path}")
# Out:
# Trained tuned model saved to: ../../models/catboost_model_final.cbm

# %%
# Step 5: Evaluate on validation set
print("\nValidation Metrics per Target:")
preds = model.predict(val_pool)
for i, target in enumerate(target_cols):
    y_true = val_df[target]
    y_pred = preds[:, i]
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    print(f"{target}: MAE={mae:.3f}, RMSE={rmse:.3f}, R2={r2:.3f}")
# Out:
# Validation Metrics per Target:
# temperature: MAE=0.229, RMSE=0.299, R2=0.991
# rainfall: MAE=1.680, RMSE=5.126, R2=0.752
# wind_speed: MAE=1.988, RMSE=2.606, R2=0.836
# precipitation: MAE=1.680, RMSE=5.126, R2=0.752
