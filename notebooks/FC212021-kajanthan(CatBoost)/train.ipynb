# %%
import pandas as pd
from catboost import CatBoostRegressor, Pool
import os

# %%
# 1. Load train data
train_df = pd.read_csv("./train_test_splits/train.csv", parse_dates=['date'])

# %%
train_df.head()
# Out:
#    location_id       date  weather_code (wmo code)  temperature_2m_max (°C)  \
# 0            0 2010-01-08                       53                     28.4
# 1            0 2010-01-09                       61                     29.1
# 2            0 2010-01-10                       51                     30.1
# 3            0 2010-01-11                       51                     29.7
# 4            0 2010-01-12                       63                     29.8
#
#    temperature_2m_min (°C)  temperature  apparent_temperature_max (°C)  \
# 0                     23.4         25.6                           32.2
# 1                     23.5         26.0                           35.4
# 2                     22.6         26.2                           35.8
# 3                     22.4         26.3                           35.5
# 4                     24.2         26.3                           36.7
#
#    apparent_temperature_min (°C)  apparent_temperature_mean (°C)  \
# ...

# %%
# 2. Define target and feature columns
TARGETS  = ['temperature', 'rainfall', 'wind_speed', 'precipitation']

# %%
# Drop target + date columns from features
FEATURES  = [col for col in train_df.columns if col not in TARGETS  + ['date']]

# %%
# Categorical features
cat_feature_cols = ['location_id', 'day_of_week']
cat_features = [i for i, c in enumerate(FEATURES) if c in cat_feature_cols]

train_pool = Pool(
    data=train_df[FEATURES ],
    label=train_df[TARGETS ],
    cat_features=cat_features
)

# %%
# 4. Initialize CatBoost Regressor (multi-output)
model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.05,
    depth=6,
    l2_leaf_reg=3,
    loss_function='MultiRMSE',
    random_seed=42,       # For reproducibility
    verbose=100
)

# %%
# 5. Train the model on train set only
model.fit(train_pool)
# Out:
# 0:	learn: 16.0343526	total: 148ms	remaining: 2m 28s
# 100:	learn: 6.7437637	total: 17.4s	remaining: 2m 34s
# 200:	learn: 6.3547415	total: 36.1s	remaining: 2m 23s
# 300:	learn: 6.0828773	total: 1m 3s	remaining: 2m 28s
# 400:	learn: 5.8908490	total: 1m 27s	remaining: 2m 11s
# 500:	learn: 5.7082874	total: 1m 48s	remaining: 1m 47s
# 600:	learn: 5.5708867	total: 2m 8s	remaining: 1m 25s
# 700:	learn: 5.4270706	total: 2m 29s	remaining: 1m 3s
# 800:	learn: 5.3078956	total: 2m 52s	remaining: 42.9s
# 900:	learn: 5.2130268	total: 3m 14s	remaining: 21.4s
# 999:	learn: 5.1136322	total: 3m 38s	remaining: 0us

# %%
# 6. Save the trained model to file
os.makedirs("models", exist_ok=True)
model_path = "models/catboost_weather_model.cbm"
model.save_model(model_path)

# %%
print(f"Training complete. Model saved to: {model_path}")
# Out:
# Training complete. Model saved to: models/catboost_weather_model.cbm

# %%
importance = model.get_feature_importance(prettified=True)
print("Feature Importance:\n", importance)
# Out:
# Feature Importance:
#                          Feature Id  Importances
# 0          weather_code (wmo code)    35.821333
# 1          precipitation_hours (h)    16.776958
# 2                  wind_speed_lag1    14.037131
# 3            sunshine_duration (s)     8.633066
# 4    apparent_temperature_max (°C)     2.587614
# 5          temperature_2m_max (°C)     2.116662
# 6                  wind_speed_lag2     1.972001
# 7          temperature_2m_min (°C)     1.809701
# 8                      day_of_year     1.354080
# 9   apparent_temperature_mean (°C)     1.305146
# 10                   rainfall_lag1     1.097447
# 11                     location_id     0.989871
# 12                temperature_lag1     0.880872
# 13                 wind_speed_lag3     0.854300
# 14           daylight_duration (s)     0.821048
# 15                 day_of_year_cos     0.818787
# 16                             day     0.813941
# 17                 day_of_year_sin     0.758803
# ...
