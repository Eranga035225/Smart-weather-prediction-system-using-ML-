# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# %%
# Load cleaned weather data
df = pd.read_csv('cleaned_weather_data.csv', parse_dates=['date'])

# %%
df.head()
# Out:
#         date  location_id  temperature  rainfall  wind_speed  precipitation
# 0 2010-01-01            0         26.0       0.0        12.2            0.0
# 1 2010-01-02            0         26.4      15.7        11.6           15.7
# 2 2010-01-03            0         28.0       0.0        13.0            0.0
# 3 2010-01-04            0         27.5       7.4        13.6            7.4
# 4 2010-01-05            0         27.7       9.6        10.3            9.6

# %%
# Define variables to process
variables = ['temperature', 'rainfall', 'wind_speed', 'precipitation']

# %%
# Create empty list to hold transformed data
stationary_data = []

# %%
# ADF test function
def adf_test(series, var_name, loc):
    try:
        result = adfuller(series.dropna(), autolag='AIC')
        print(f"Location {loc} - {var_name} ADF Statistic: {result[0]:.4f}, p-value: {result[1]:.4f}")
        for key, val in result[4].items():
            print(f"   Critical Value ({key}): {val:.4f}")
        if result[1] < 0.05:
            print(f"   {var_name} is stationary (reject H0)")
            return True
        else:
            print(f"   {var_name} is NOT stationary (fail to reject H0)")
            return False
    except Exception as e:
        print(f"   ADF test failed for {var_name} at location {loc}: {e}")
        return False

# %%
# Process each location
for loc in df['location_id'].unique():
    print(f"\nProcessing location: {loc}")
    loc_df = df[df['location_id'] == loc].sort_values('date').copy()
    loc_df.set_index('date', inplace=True)

    for var in variables:
        print(f"\nChecking stationarity for '{var}' at location {loc}:")
        is_stationary = adf_test(loc_df[var], var, loc)

        if not is_stationary:
            new_var = var + '_diff'
            print(f"Applying first differencing to '{var}' → '{new_var}'")
            loc_df[new_var] = loc_df[var].diff()

            print(f"Re-checking stationarity for '{new_var}' at location {loc}:")
            is_stationary_after = adf_test(loc_df[new_var], new_var, loc)

            if is_stationary_after:
                loc_df.drop(columns=[var], inplace=True)
            else:
                print(f"Warning: '{new_var}' is still not stationary")

    # Drop NaNs from differencing
    loc_df.dropna(inplace=True)

    # Add location_id column back
    loc_df['location_id'] = loc

    # Store the processed data
    stationary_data.append(loc_df.reset_index())
# Out:
# Processing location: 0
#
# Checking stationarity for 'temperature' at location 0:
# Location 0 - temperature ADF Statistic: -4.5997, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 0:
# Location 0 - rainfall ADF Statistic: -10.0279, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 0:
# Location 0 - wind_speed ADF Statistic: -5.6065, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 0:
# Location 0 - precipitation ADF Statistic: -10.0279, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 1
#
# Checking stationarity for 'temperature' at location 1:
# Location 1 - temperature ADF Statistic: -4.8300, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 1:
# Location 1 - rainfall ADF Statistic: -9.9830, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 1:
# Location 1 - wind_speed ADF Statistic: -7.1475, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 1:
# Location 1 - precipitation ADF Statistic: -9.9830, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 2
#
# Checking stationarity for 'temperature' at location 2:
# Location 2 - temperature ADF Statistic: -4.5767, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 2:
# Location 2 - rainfall ADF Statistic: -9.8984, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 2:
# Location 2 - wind_speed ADF Statistic: -6.0703, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 2:
# Location 2 - precipitation ADF Statistic: -9.8984, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 3
#
# Checking stationarity for 'temperature' at location 3:
# Location 3 - temperature ADF Statistic: -4.5464, p-value: 0.0002
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 3:
# Location 3 - rainfall ADF Statistic: -9.6796, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 3:
# Location 3 - wind_speed ADF Statistic: -4.8575, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 3:
# Location 3 - precipitation ADF Statistic: -9.6796, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 4
#
# Checking stationarity for 'temperature' at location 4:
# Location 4 - temperature ADF Statistic: -4.8680, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 4:
# Location 4 - rainfall ADF Statistic: -9.4915, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 4:
# Location 4 - wind_speed ADF Statistic: -6.6755, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 4:
# Location 4 - precipitation ADF Statistic: -9.4915, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 5
#
# Checking stationarity for 'temperature' at location 5:
# Location 5 - temperature ADF Statistic: -2.3584, p-value: 0.1538
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is NOT stationary (fail to reject H0)
# Applying first differencing to 'temperature' → 'temperature_diff'
# Re-checking stationarity for 'temperature_diff' at location 5:
# Location 5 - temperature_diff ADF Statistic: -18.9511, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature_diff is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 5:
# Location 5 - rainfall ADF Statistic: -9.5282, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 5:
# Location 5 - wind_speed ADF Statistic: -5.7786, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 5:
# Location 5 - precipitation ADF Statistic: -9.5282, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 6
#
# Checking stationarity for 'temperature' at location 6:
# Location 6 - temperature ADF Statistic: -4.6724, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 6:
# Location 6 - rainfall ADF Statistic: -8.9514, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 6:
# Location 6 - wind_speed ADF Statistic: -5.2619, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 6:
# Location 6 - precipitation ADF Statistic: -8.9514, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 7
#
# Checking stationarity for 'temperature' at location 7:
# Location 7 - temperature ADF Statistic: -4.2160, p-value: 0.0006
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 7:
# Location 7 - rainfall ADF Statistic: -9.3712, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 7:
# Location 7 - wind_speed ADF Statistic: -4.2673, p-value: 0.0005
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 7:
# Location 7 - precipitation ADF Statistic: -9.3712, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 8
#
# Checking stationarity for 'temperature' at location 8:
# Location 8 - temperature ADF Statistic: -4.7150, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 8:
# Location 8 - rainfall ADF Statistic: -9.6815, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 8:
# Location 8 - wind_speed ADF Statistic: -5.9220, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 8:
# Location 8 - precipitation ADF Statistic: -9.6815, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 9
#
# Checking stationarity for 'temperature' at location 9:
# Location 9 - temperature ADF Statistic: -4.2210, p-value: 0.0006
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 9:
# Location 9 - rainfall ADF Statistic: -8.8620, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 9:
# Location 9 - wind_speed ADF Statistic: -6.0807, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 9:
# Location 9 - precipitation ADF Statistic: -8.8620, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 10
#
# Checking stationarity for 'temperature' at location 10:
# Location 10 - temperature ADF Statistic: -4.3754, p-value: 0.0003
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 10:
# Location 10 - rainfall ADF Statistic: -8.3120, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 10:
# Location 10 - wind_speed ADF Statistic: -7.6634, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 10:
# Location 10 - precipitation ADF Statistic: -8.3120, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 11
#
# Checking stationarity for 'temperature' at location 11:
# Location 11 - temperature ADF Statistic: -4.3454, p-value: 0.0004
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 11:
# Location 11 - rainfall ADF Statistic: -8.8343, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 11:
# Location 11 - wind_speed ADF Statistic: -7.2330, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 11:
# Location 11 - precipitation ADF Statistic: -8.8343, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 12
#
# Checking stationarity for 'temperature' at location 12:
# Location 12 - temperature ADF Statistic: -4.6800, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 12:
# Location 12 - rainfall ADF Statistic: -8.5993, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 12:
# Location 12 - wind_speed ADF Statistic: -7.3556, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 12:
# Location 12 - precipitation ADF Statistic: -8.5993, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 13
#
# Checking stationarity for 'temperature' at location 13:
# Location 13 - temperature ADF Statistic: -4.2244, p-value: 0.0006
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 13:
# Location 13 - rainfall ADF Statistic: -8.3902, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 13:
# Location 13 - wind_speed ADF Statistic: -8.1330, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 13:
# Location 13 - precipitation ADF Statistic: -8.3902, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 14
#
# Checking stationarity for 'temperature' at location 14:
# Location 14 - temperature ADF Statistic: -4.0182, p-value: 0.0013
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 14:
# Location 14 - rainfall ADF Statistic: -8.2531, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 14:
# Location 14 - wind_speed ADF Statistic: -7.5252, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 14:
# Location 14 - precipitation ADF Statistic: -8.2531, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 15
#
# Checking stationarity for 'temperature' at location 15:
# Location 15 - temperature ADF Statistic: -4.0433, p-value: 0.0012
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 15:
# Location 15 - rainfall ADF Statistic: -8.8379, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 15:
# Location 15 - wind_speed ADF Statistic: -8.1832, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 15:
# Location 15 - precipitation ADF Statistic: -8.8379, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 16
#
# Checking stationarity for 'temperature' at location 16:
# Location 16 - temperature ADF Statistic: -4.2684, p-value: 0.0005
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 16:
# Location 16 - rainfall ADF Statistic: -7.8832, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 16:
# Location 16 - wind_speed ADF Statistic: -6.1239, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 16:
# Location 16 - precipitation ADF Statistic: -7.8832, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 17
#
# Checking stationarity for 'temperature' at location 17:
# Location 17 - temperature ADF Statistic: -5.2200, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 17:
# Location 17 - rainfall ADF Statistic: -10.0339, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 17:
# Location 17 - wind_speed ADF Statistic: -6.9738, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 17:
# Location 17 - precipitation ADF Statistic: -10.0339, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 18
#
# Checking stationarity for 'temperature' at location 18:
# Location 18 - temperature ADF Statistic: -4.7647, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 18:
# Location 18 - rainfall ADF Statistic: -10.2845, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 18:
# Location 18 - wind_speed ADF Statistic: -5.8443, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 18:
# Location 18 - precipitation ADF Statistic: -10.2845, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 19
#
# Checking stationarity for 'temperature' at location 19:
# Location 19 - temperature ADF Statistic: -4.8955, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 19:
# Location 19 - rainfall ADF Statistic: -9.2357, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 19:
# Location 19 - wind_speed ADF Statistic: -6.5641, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 19:
# Location 19 - precipitation ADF Statistic: -9.2357, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 20
#
# Checking stationarity for 'temperature' at location 20:
# Location 20 - temperature ADF Statistic: -4.5049, p-value: 0.0002
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 20:
# Location 20 - rainfall ADF Statistic: -8.1769, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 20:
# Location 20 - wind_speed ADF Statistic: -5.9897, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 20:
# Location 20 - precipitation ADF Statistic: -8.1769, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 21
#
# Checking stationarity for 'temperature' at location 21:
# Location 21 - temperature ADF Statistic: -4.2248, p-value: 0.0006
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 21:
# Location 21 - rainfall ADF Statistic: -9.2552, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 21:
# Location 21 - wind_speed ADF Statistic: -6.4258, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 21:
# Location 21 - precipitation ADF Statistic: -9.2552, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 22
#
# Checking stationarity for 'temperature' at location 22:
# Location 22 - temperature ADF Statistic: -4.4278, p-value: 0.0003
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 22:
# Location 22 - rainfall ADF Statistic: -8.9151, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 22:
# Location 22 - wind_speed ADF Statistic: -5.5659, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 22:
# Location 22 - precipitation ADF Statistic: -8.9151, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 23
#
# Checking stationarity for 'temperature' at location 23:
# Location 23 - temperature ADF Statistic: -3.0145, p-value: 0.0336
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 23:
# Location 23 - rainfall ADF Statistic: -8.3327, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 23:
# Location 23 - wind_speed ADF Statistic: -4.6538, p-value: 0.0001
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 23:
# Location 23 - precipitation ADF Statistic: -8.3327, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 24
#
# Checking stationarity for 'temperature' at location 24:
# Location 24 - temperature ADF Statistic: -4.1968, p-value: 0.0007
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 24:
# Location 24 - rainfall ADF Statistic: -10.1819, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 24:
# Location 24 - wind_speed ADF Statistic: -6.2152, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 24:
# Location 24 - precipitation ADF Statistic: -10.1819, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 25
#
# Checking stationarity for 'temperature' at location 25:
# Location 25 - temperature ADF Statistic: -3.7251, p-value: 0.0038
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 25:
# Location 25 - rainfall ADF Statistic: -8.8791, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 25:
# Location 25 - wind_speed ADF Statistic: -6.4903, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 25:
# Location 25 - precipitation ADF Statistic: -8.8791, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)
#
# Processing location: 26
#
# Checking stationarity for 'temperature' at location 26:
# Location 26 - temperature ADF Statistic: -3.3149, p-value: 0.0142
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    temperature is stationary (reject H0)
#
# Checking stationarity for 'rainfall' at location 26:
# Location 26 - rainfall ADF Statistic: -9.0647, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    rainfall is stationary (reject H0)
#
# Checking stationarity for 'wind_speed' at location 26:
# Location 26 - wind_speed ADF Statistic: -6.5949, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    wind_speed is stationary (reject H0)
#
# Checking stationarity for 'precipitation' at location 26:
# Location 26 - precipitation ADF Statistic: -9.0647, p-value: 0.0000
#    Critical Value (1%): -3.4316
#    Critical Value (5%): -2.8621
#    Critical Value (10%): -2.5671
#    precipitation is stationary (reject H0)

# %%
# Combine all processed data
final_stationary_df = pd.concat(stationary_data, ignore_index=True)

# %%
# Save final stationary dataset
final_stationary_df.to_csv('stationary_weather_data.csv', index=False)

print("\nAll locations processed.")
print("Saved stationary dataset as 'stationary_weather_data.csv'")
# Out:
# All locations processed.
# Saved stationary dataset as 'stationary_weather_data.csv'
