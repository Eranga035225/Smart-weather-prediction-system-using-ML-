# %%
import os
import pandas as pd
import pickle
from statsmodels.tsa.api import VAR
import numpy as np

# %%
model_save_folder = 'trained_var_models'
os.makedirs(model_save_folder, exist_ok=True)

# %%
def train_and_save_var(location_train_csv):
    location_name = os.path.basename(location_train_csv).replace('_train.csv', '')
    print(f"\nTraining VAR model for location: {location_name}")

    df = pd.read_csv(location_train_csv, parse_dates=['date'])
    # Drop 'date' and 'location_id' columns
    df_numeric = df.drop(columns=['date', 'location_id'], errors='ignore')

    # Drop one of the perfectly correlated variables to reduce multicollinearity
    if 'precipitation' in df_numeric.columns:
        df_numeric = df_numeric.drop(columns=['precipitation'])
        print("Dropped 'precipitation' due to perfect correlation with 'rainfall'.")

    # Drop columns with all NaNs and rows with any NaN
    df_numeric = df_numeric.dropna(axis=1, how='all').dropna()

    print("Variance per variable:")
    print(df_numeric.var())
    print("Correlation matrix:")
    print(df_numeric.corr())

    n_obs = len(df_numeric)
    n_vars = df_numeric.shape[1]

    if n_obs < (n_vars + 1):
        print(f"Not enough observations ({n_obs}) for number of variables ({n_vars}), skipping.")
        return

    fixed_lag = 1  # fixed lag order

    model = VAR(df_numeric)

    try:
        var_model = model.fit(fixed_lag, trend='c')
        print(f"Fitted VAR model with lag {fixed_lag}")
    except np.linalg.LinAlgError as e:
        print(f"LinAlgError during fit: {e}, trying lag=1 again without constant")
        var_model = model.fit(fixed_lag, trend='nc')

    try:
        print(var_model.summary())
    except np.linalg.LinAlgError as e:
        print(f"Cannot print summary due to LinAlgError: {e}")

    model_path = os.path.join(model_save_folder, f'{location_name}_var_model.pkl')
    with open(model_path, 'wb') as f:
        pickle.dump(var_model, f)
    print(f"Saved VAR model to {model_path}")

# %%
# Example usage:
train_folder = 'train_val_test_splits'
for file in os.listdir(train_folder):
    if file.endswith('_train.csv'):
        train_csv_path = os.path.join(train_folder, file)
        train_and_save_var(train_csv_path)
# Out:
# Training VAR model for location: 0
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      0.915459
# rainfall       115.268661
# wind_speed      20.538635
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.355362    0.003182
# rainfall       -0.355362  1.000000    0.039134
# wind_speed      0.003182  0.039134    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.38183
# Nobs:                     3690.00    HQIC:                   6.36882
# Log likelihood:          -27432.9    FPE:                    579.188
# AIC:                      6.36163    Det(Omega_mle):         577.308
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.498758         0.349070           24.347           0.000
# L1.temperature         0.686806         0.012937           53.089           0.000
# L1.rainfall            0.002617         0.001154            2.267           0.023
# L1.wind_speed         -0.012013         0.002556           -4.700           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.720328         5.119196            1.313           0.189
# L1.temperature        -0.042378         0.189723           -0.223           0.823
# L1.rainfall            0.280908         0.016924           16.598           0.000
# L1.wind_speed         -0.015759         0.037480           -0.420           0.674
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -3.999480         1.813267           -2.206           0.027
# L1.temperature         0.381442         0.067202            5.676           0.000
# L1.rainfall            0.019588         0.005995            3.268           0.001
# L1.wind_speed          0.586233         0.013276           44.158           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.415183   -0.016876
# rainfall         -0.415183  1.000000    0.041202
# wind_speed       -0.016876  0.041202    1.000000
#
#
#
# Saved VAR model to trained_var_models\0_var_model.pkl
#
# Training VAR model for location: 10
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     3.544219
# rainfall       75.132662
# wind_speed     39.987393
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.366680    0.270406
# rainfall       -0.366680  1.000000   -0.036427
# wind_speed      0.270406 -0.036427    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.68052
# Nobs:                     3690.00    HQIC:                   7.66751
# Log likelihood:          -29828.9    FPE:                    2122.42
# AIC:                      7.66031    Det(Omega_mle):         2115.54
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.193747         0.318228           19.463           0.000
# L1.temperature         0.770171         0.011778           65.391           0.000
# L1.rainfall            0.005547         0.002464            2.251           0.024
# L1.wind_speed          0.007854         0.003265            2.406           0.016
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 12.109533         2.160477            5.605           0.000
# L1.temperature        -0.299839         0.079961           -3.750           0.000
# L1.rainfall            0.294266         0.016731           17.588           0.000
# L1.wind_speed         -0.077263         0.022167           -3.486           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -2.311148         1.342745           -1.721           0.085
# L1.temperature         0.433918         0.049696            8.731           0.000
# L1.rainfall           -0.001286         0.010399           -0.124           0.902
# L1.wind_speed          0.547651         0.013777           39.752           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.377855    0.083614
# rainfall         -0.377855  1.000000    0.046021
# wind_speed        0.083614  0.046021    1.000000
#
#
#
# Saved VAR model to trained_var_models\10_var_model.pkl
#
# Training VAR model for location: 11
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     2.132445
# rainfall       65.423243
# wind_speed     59.431759
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.336855    0.344123
# rainfall       -0.336855  1.000000   -0.141991
# wind_speed      0.344123 -0.141991    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.41517
# Nobs:                     3690.00    HQIC:                   7.40215
# Log likelihood:          -29339.4    FPE:                    1627.76
# AIC:                      7.39496    Det(Omega_mle):         1622.48
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.612805         0.326141           20.276           0.000
# L1.temperature         0.758022         0.012241           61.926           0.000
# L1.rainfall            0.006942         0.002096            3.312           0.001
# L1.wind_speed          0.001166         0.002206            0.529           0.597
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 14.757416         2.631943            5.607           0.000
# L1.temperature        -0.382015         0.098782           -3.867           0.000
# L1.rainfall            0.196155         0.016916           11.596           0.000
# L1.wind_speed         -0.078655         0.017804           -4.418           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -11.917284         1.928535           -6.179           0.000
# L1.temperature         0.791324         0.072382           10.933           0.000
# L1.rainfall           -0.002070         0.012395           -0.167           0.867
# L1.wind_speed          0.602432         0.013046           46.178           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.347952    0.150582
# rainfall         -0.347952  1.000000   -0.057368
# wind_speed        0.150582 -0.057368    1.000000
#
#
#
# Saved VAR model to trained_var_models\11_var_model.pkl
#
# Training VAR model for location: 12
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     3.603827
# rainfall       66.073918
# wind_speed     37.715673
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.347866    0.409876
# rainfall       -0.347866  1.000000   -0.246409
# wind_speed      0.409876 -0.246409    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.47126
# Nobs:                     3690.00    HQIC:                   7.45825
# Log likelihood:          -29442.9    FPE:                    1721.68
# AIC:                      7.45106    Det(Omega_mle):         1716.10
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.894372         0.321988           21.412           0.000
# L1.temperature         0.734310         0.012451           58.976           0.000
# L1.rainfall            0.003627         0.002737            1.325           0.185
# L1.wind_speed          0.014386         0.003724            3.863           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  9.548934         1.996985            4.782           0.000
# L1.temperature        -0.171442         0.077221           -2.220           0.026
# L1.rainfall            0.224831         0.016973           13.246           0.000
# L1.wind_speed         -0.122737         0.023099           -5.313           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -5.305307         1.197002           -4.432           0.000
# L1.temperature         0.466244         0.046287           10.073           0.000
# L1.rainfall            0.026388         0.010174            2.594           0.009
# L1.wind_speed          0.586295         0.013846           42.345           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.361764    0.217452
# rainfall         -0.361764  1.000000   -0.187215
# wind_speed        0.217452 -0.187215    1.000000
#
#
#
# Saved VAR model to trained_var_models\12_var_model.pkl
#
# Training VAR model for location: 13
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     3.283508
# rainfall       81.584082
# wind_speed     29.571269
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.417584    0.393125
# rainfall       -0.417584  1.000000   -0.012570
# wind_speed      0.393125 -0.012570    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.23153
# Nobs:                     3690.00    HQIC:                   7.21852
# Log likelihood:          -29000.5    FPE:                    1354.68
# AIC:                      7.21132    Det(Omega_mle):         1350.29
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  5.900129         0.332772           17.730           0.000
# L1.temperature         0.783513         0.012750           61.452           0.000
# L1.rainfall            0.008579         0.002352            3.647           0.000
# L1.wind_speed          0.004035         0.003861            1.045           0.296
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 13.335911         2.411741            5.530           0.000
# L1.temperature        -0.355441         0.092405           -3.847           0.000
# L1.rainfall            0.340559         0.017047           19.978           0.000
# L1.wind_speed         -0.057069         0.027985           -2.039           0.041
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -3.952858         1.270743           -3.111           0.002
# L1.temperature         0.499495         0.048688           10.259           0.000
# L1.rainfall            0.010384         0.008982            1.156           0.248
# L1.wind_speed          0.503733         0.014745           34.162           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.433298    0.211732
# rainfall         -0.433298  1.000000    0.070017
# wind_speed        0.211732  0.070017    1.000000
#
#
#
# Saved VAR model to trained_var_models\13_var_model.pkl
#
# Training VAR model for location: 14
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      3.369965
# rainfall       121.842626
# wind_speed      20.906668
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.404365   -0.052803
# rainfall       -0.404365  1.000000    0.152969
# wind_speed     -0.052803  0.152969    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.57050
# Nobs:                     3690.00    HQIC:                   7.55748
# Log likelihood:          -29625.9    FPE:                    1901.30
# AIC:                      7.55029    Det(Omega_mle):         1895.13
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  5.649473         0.312924           18.054           0.000
# L1.temperature         0.799999         0.010945           73.093           0.000
# L1.rainfall            0.002938         0.001839            1.597           0.110
# L1.wind_speed         -0.007966         0.004068           -1.958           0.050
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 25.214776         2.864050            8.804           0.000
# L1.temperature        -0.812537         0.100174           -8.111           0.000
# L1.rainfall            0.303343         0.016832           18.022           0.000
# L1.wind_speed          0.023471         0.037228            0.630           0.528
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 12.601467         1.161493           10.849           0.000
# L1.temperature        -0.111241         0.040625           -2.738           0.006
# L1.rainfall            0.007177         0.006826            1.051           0.293
# L1.wind_speed          0.415389         0.015098           27.513           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.361166    0.023841
# rainfall         -0.361166  1.000000    0.130207
# wind_speed        0.023841  0.130207    1.000000
#
#
#
# Saved VAR model to trained_var_models\14_var_model.pkl
#
# Training VAR model for location: 15
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     3.729877
# rainfall       96.336456
# wind_speed     15.763353
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.386590   -0.055763
# rainfall       -0.386590  1.000000    0.001057
# wind_speed     -0.055763  0.001057    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.13136
# Nobs:                     3690.00    HQIC:                   7.11835
# Log likelihood:          -28815.7    FPE:                    1225.57
# AIC:                      7.11116    Det(Omega_mle):         1221.59
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  5.473743         0.310567           17.625           0.000
# L1.temperature         0.801665         0.010815           74.127           0.000
# L1.rainfall            0.002944         0.002124            1.386           0.166
# L1.wind_speed         -0.005622         0.004852           -1.159           0.247
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 20.121851         2.442590            8.238           0.000
# L1.temperature        -0.613267         0.085058           -7.210           0.000
# L1.rainfall            0.289339         0.016708           17.318           0.000
# L1.wind_speed         -0.004534         0.038161           -0.119           0.905
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  9.587219         0.930276           10.306           0.000
# L1.temperature        -0.087786         0.032395           -2.710           0.007
# L1.rainfall           -0.001902         0.006363           -0.299           0.765
# L1.wind_speed          0.468632         0.014534           32.244           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.363417    0.007227
# rainfall         -0.363417  1.000000   -0.011535
# wind_speed        0.007227 -0.011535    1.000000
#
#
#
# Saved VAR model to trained_var_models\15_var_model.pkl
#
# Training VAR model for location: 16
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      3.028626
# rainfall       100.753589
# wind_speed      39.155353
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.413753    0.428994
# rainfall       -0.413753  1.000000   -0.034919
# wind_speed      0.428994 -0.034919    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.56184
# Nobs:                     3690.00    HQIC:                   7.54882
# Log likelihood:          -29610.0    FPE:                    1884.90
# AIC:                      7.54163    Det(Omega_mle):         1878.79
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.276010         0.338623           18.534           0.000
# L1.temperature         0.771689         0.012991           59.403           0.000
# L1.rainfall            0.002628         0.002036            1.291           0.197
# L1.wind_speed          0.002189         0.003292            0.665           0.506
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 19.367568         2.784200            6.956           0.000
# L1.temperature        -0.595580         0.106812           -5.576           0.000
# L1.rainfall            0.356911         0.016739           21.323           0.000
# L1.wind_speed         -0.016032         0.027067           -0.592           0.554
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -6.462456         1.469387           -4.398           0.000
# L1.temperature         0.566946         0.056371           10.057           0.000
# L1.rainfall            0.012231         0.008834            1.385           0.166
# L1.wind_speed          0.555110         0.014285           38.861           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.381988    0.255722
# rainfall         -0.381988  1.000000    0.049106
# wind_speed        0.255722  0.049106    1.000000
#
#
#
# Saved VAR model to trained_var_models\16_var_model.pkl
#
# Training VAR model for location: 17
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      1.499616
# rainfall       130.778239
# wind_speed      22.297658
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.326146   -0.028634
# rainfall       -0.326146  1.000000   -0.148368
# wind_speed     -0.028634 -0.148368    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.07099
# Nobs:                     3690.00    HQIC:                   7.05798
# Log likelihood:          -28704.4    FPE:                    1153.77
# AIC:                      7.05079    Det(Omega_mle):         1150.02
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.278252         0.341945           24.209           0.000
# L1.temperature         0.680214         0.012847           52.947           0.000
# L1.rainfall            0.000818         0.001391            0.588           0.557
# L1.wind_speed         -0.002577         0.003186           -0.809           0.419
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 11.581372         4.086534            2.834           0.005
# L1.temperature        -0.225976         0.153533           -1.472           0.141
# L1.rainfall            0.320539         0.016624           19.281           0.000
# L1.wind_speed         -0.122278         0.038078           -3.211           0.001
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  4.638288         1.435939            3.230           0.001
# L1.temperature         0.055973         0.053949            1.038           0.299
# L1.rainfall            0.008423         0.005842            1.442           0.149
# L1.wind_speed          0.602841         0.013380           45.056           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.352024   -0.026583
# rainfall         -0.352024  1.000000   -0.125532
# wind_speed       -0.026583 -0.125532    1.000000
#
#
#
# Saved VAR model to trained_var_models\17_var_model.pkl
#
# Training VAR model for location: 18
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     1.233273
# rainfall       85.509643
# wind_speed     29.760753
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.259890    0.178466
# rainfall       -0.259890  1.000000   -0.126122
# wind_speed      0.178466 -0.126122    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.58322
# Nobs:                     3690.00    HQIC:                   6.57020
# Log likelihood:          -27804.4    FPE:                    708.402
# AIC:                      6.56301    Det(Omega_mle):         706.103
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.057806         0.332139           24.260           0.000
# L1.temperature         0.702018         0.012370           56.750           0.000
# L1.rainfall            0.001841         0.001474            1.249           0.212
# L1.wind_speed         -0.001252         0.002453           -0.511           0.610
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  1.238944         3.632239            0.341           0.733
# L1.temperature         0.148972         0.135282            1.101           0.271
# L1.rainfall            0.325349         0.016115           20.190           0.000
# L1.wind_speed         -0.121527         0.026824           -4.530           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -2.733384         1.693202           -1.614           0.106
# L1.temperature         0.328404         0.063063            5.208           0.000
# L1.rainfall            0.013330         0.007512            1.775           0.076
# L1.wind_speed          0.656533         0.012504           52.504           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.311149    0.110401
# rainfall         -0.311149  1.000000   -0.080432
# wind_speed        0.110401 -0.080432    1.000000
#
#
#
# Saved VAR model to trained_var_models\18_var_model.pkl
#
# Training VAR model for location: 19
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     2.503427
# rainfall       82.670832
# wind_speed     40.833852
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.325892    0.321803
# rainfall       -0.325892  1.000000   -0.222850
# wind_speed      0.321803 -0.222850    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.45250
# Nobs:                     3690.00    HQIC:                   7.43948
# Log likelihood:          -29408.2    FPE:                    1689.67
# AIC:                      7.43229    Det(Omega_mle):         1684.19
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  7.793907         0.328502           23.726           0.000
# L1.temperature         0.699379         0.012586           55.567           0.000
# L1.rainfall           -0.000277         0.002127           -0.130           0.896
# L1.wind_speed          0.012811         0.003024            4.237           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  9.708035         2.572559            3.774           0.000
# L1.temperature        -0.175551         0.098565           -1.781           0.075
# L1.rainfall            0.273836         0.016658           16.438           0.000
# L1.wind_speed         -0.125314         0.023678           -5.292           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -6.014978         1.386937           -4.337           0.000
# L1.temperature         0.459916         0.053139            8.655           0.000
# L1.rainfall            0.020951         0.008981            2.333           0.020
# L1.wind_speed          0.648962         0.012765           50.837           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.324244    0.133838
# rainfall         -0.324244  1.000000   -0.162436
# wind_speed        0.133838 -0.162436    1.000000
#
#
#
# Saved VAR model to trained_var_models\19_var_model.pkl
#
# Training VAR model for location: 1
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      1.011405
# rainfall       112.694221
# wind_speed      17.044365
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.398524   -0.078756
# rainfall       -0.398524  1.000000   -0.015371
# wind_speed     -0.078756 -0.015371    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.31898
# Nobs:                     3690.00    HQIC:                   6.30597
# Log likelihood:          -27316.9    FPE:                    543.906
# AIC:                      6.29878    Det(Omega_mle):         542.141
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.533764         0.362032           23.572           0.000
# L1.temperature         0.681991         0.013280           51.353           0.000
# L1.rainfall            0.002360         0.001255            1.881           0.060
# L1.wind_speed         -0.009252         0.002968           -3.118           0.002
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 11.298616         4.927151            2.293           0.022
# L1.temperature        -0.204403         0.180742           -1.131           0.258
# L1.rainfall            0.304925         0.017075           17.858           0.000
# L1.wind_speed         -0.055262         0.040387           -1.368           0.171
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  3.769902         1.707466            2.208           0.027
# L1.temperature         0.109688         0.062635            1.751           0.080
# L1.rainfall            0.013634         0.005917            2.304           0.021
# L1.wind_speed          0.534666         0.013996           38.202           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.447028   -0.062301
# rainfall         -0.447028  1.000000   -0.011530
# wind_speed       -0.062301 -0.011530    1.000000
#
#
#
# Saved VAR model to trained_var_models\1_var_model.pkl
#
# Training VAR model for location: 20
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      4.204943
# rainfall       110.718051
# wind_speed      50.267534
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.347338    0.556575
# rainfall       -0.347338  1.000000   -0.205554
# wind_speed      0.556575 -0.205554    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    8.18658
# Nobs:                     3690.00    HQIC:                   8.17357
# Log likelihood:          -30762.6    FPE:                    3520.56
# AIC:                      8.16638    Det(Omega_mle):         3509.14
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.669593         0.333081           20.024           0.000
# L1.temperature         0.745852         0.013180           56.588           0.000
# L1.rainfall            0.001761         0.002180            0.807           0.419
# L1.wind_speed          0.013993         0.003654            3.830           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 15.409013         2.549018            6.045           0.000
# L1.temperature        -0.385889         0.100868           -3.826           0.000
# L1.rainfall            0.245222         0.016687           14.695           0.000
# L1.wind_speed         -0.109470         0.027963           -3.915           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -8.937341         1.298448           -6.883           0.000
# L1.temperature         0.588152         0.051381           11.447           0.000
# L1.rainfall            0.016242         0.008500            1.911           0.056
# L1.wind_speed          0.592887         0.014244           41.623           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.317013    0.346030
# rainfall         -0.317013  1.000000   -0.117055
# wind_speed        0.346030 -0.117055    1.000000
#
#
#
# Saved VAR model to trained_var_models\20_var_model.pkl
#
# Training VAR model for location: 21
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature      3.422551
# rainfall       130.356169
# wind_speed      15.469646
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.268829    0.370132
# rainfall       -0.268829  1.000000   -0.253497
# wind_speed      0.370132 -0.253497    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.23062
# Nobs:                     3690.00    HQIC:                   7.21760
# Log likelihood:          -28998.9    FPE:                    1353.45
# AIC:                      7.21041    Det(Omega_mle):         1349.06
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  5.272467         0.253647           20.787           0.000
# L1.temperature         0.766477         0.011206           68.397           0.000
# L1.rainfall           -0.000787         0.001744           -0.451           0.652
# L1.wind_speed          0.019939         0.005248            3.799           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 12.569056         2.409874            5.216           0.000
# L1.temperature        -0.234962         0.106470           -2.207           0.027
# L1.rainfall            0.243200         0.016566           14.680           0.000
# L1.wind_speed         -0.278173         0.049860           -5.579           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.894769         0.695105           -1.287           0.198
# L1.temperature         0.239894         0.030710            7.812           0.000
# L1.rainfall            0.005571         0.004778            1.166           0.244
# L1.wind_speed          0.554704         0.014382           38.570           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.260219    0.209992
# rainfall         -0.260219  1.000000   -0.192901
# wind_speed        0.209992 -0.192901    1.000000
#
#
#
# ...
# const                       5.090608         0.429143           11.862           0.000
# L1.rainfall                 0.327749         0.015862           20.663           0.000
# L1.wind_speed              -0.031484         0.032315           -0.974           0.330
# L1.temperature_diff         0.565747         0.265373            2.132           0.033
# ======================================================================================
#
# Results for equation wind_speed
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       3.349808         0.161217           20.778           0.000
# L1.rainfall                 0.014447         0.005959            2.424           0.015
# L1.wind_speed               0.692315         0.012140           57.029           0.000
# L1.temperature_diff         0.230995         0.099693            2.317           0.021
# ======================================================================================
#
# Results for equation temperature_diff
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.083350         0.026568            3.137           0.002
# L1.rainfall                 0.002480         0.000982            2.525           0.012
# L1.wind_speed              -0.009053         0.002001           -4.525           0.000
# L1.temperature_diff        -0.194351         0.016429          -11.830           0.000
# ======================================================================================
#
# Correlation matrix of residuals
#                     rainfall  wind_speed  temperature_diff
# rainfall            1.000000   -0.096508         -0.186104
# wind_speed         -0.096508    1.000000         -0.101356
# temperature_diff   -0.186104   -0.101356          1.000000
#
#
#
# Saved VAR model to trained_var_models\5_var_model.pkl
#
# Training VAR model for location: 6
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     0.629819
# rainfall       81.961302
# wind_speed     41.667927
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.335181    0.160625
# rainfall       -0.335181  1.000000    0.052647
# wind_speed      0.160625  0.052647    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.24161
# Nobs:                     3690.00    HQIC:                   6.22860
# Log likelihood:          -27174.1    FPE:                    503.411
# AIC:                      6.22141    Det(Omega_mle):         501.778
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.891673         0.360355           24.675           0.000
# L1.temperature         0.668819         0.013655           48.981           0.000
# L1.rainfall            0.005624         0.001183            4.752           0.000
# L1.wind_speed         -0.009003         0.001584           -5.683           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -3.024061         5.078624           -0.595           0.552
# L1.temperature         0.278286         0.192441            1.446           0.148
# L1.rainfall            0.326914         0.016679           19.601           0.000
# L1.wind_speed          0.004563         0.022324            0.204           0.838
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -13.731344         2.831251           -4.850           0.000
# L1.temperature         0.739023         0.107283            6.889           0.000
# L1.rainfall            0.046204         0.009298            4.969           0.000
# L1.wind_speed          0.647184         0.012445           52.003           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.409234    0.156539
# rainfall         -0.409234  1.000000    0.033755
# wind_speed        0.156539  0.033755    1.000000
#
#
#
# Saved VAR model to trained_var_models\6_var_model.pkl
#
# Training VAR model for location: 7
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     0.639542
# rainfall       63.812718
# wind_speed     54.610342
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.360370    0.174259
# rainfall       -0.360370  1.000000    0.001451
# wind_speed      0.174259  0.001451    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.15639
# Nobs:                     3690.00    HQIC:                   6.14337
# Log likelihood:          -27016.9    FPE:                    462.285
# AIC:                      6.13618    Det(Omega_mle):         460.785
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  8.477461         0.358089           23.674           0.000
# L1.temperature         0.683738         0.013526           50.551           0.000
# L1.rainfall            0.005481         0.001333            4.111           0.000
# L1.wind_speed         -0.005643         0.001366           -4.131           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  2.283968         4.506997            0.507           0.612
# L1.temperature         0.068325         0.170239            0.401           0.688
# L1.rainfall            0.320163         0.016783           19.077           0.000
# L1.wind_speed         -0.012474         0.017191           -0.726           0.468
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -16.160703         3.133565           -5.157           0.000
# L1.temperature         0.833811         0.118362            7.045           0.000
# L1.rainfall            0.050032         0.011669            4.288           0.000
# L1.wind_speed          0.680304         0.011952           56.918           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.424504    0.148351
# rainfall         -0.424504  1.000000    0.001119
# wind_speed        0.148351  0.001119    1.000000
#
#
#
# Saved VAR model to trained_var_models\7_var_model.pkl
#
# Training VAR model for location: 8
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     1.204590
# rainfall       64.861082
# wind_speed     53.043721
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.387047    0.524212
# rainfall       -0.387047  1.000000   -0.237618
# wind_speed      0.524212 -0.237618    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    6.65379
# Nobs:                     3690.00    HQIC:                   6.64078
# Log likelihood:          -27934.6    FPE:                    760.204
# AIC:                      6.63359    Det(Omega_mle):         757.737
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  9.280691         0.384329           24.148           0.000
# L1.temperature         0.652174         0.014714           44.325           0.000
# L1.rainfall           -0.000938         0.001758           -0.534           0.594
# L1.wind_speed          0.010085         0.002105            4.790           0.000
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 12.362228         3.667008            3.371           0.001
# L1.temperature        -0.306508         0.140387           -2.183           0.029
# L1.rainfall            0.297554         0.016771           17.742           0.000
# L1.wind_speed         -0.085585         0.020087           -4.261           0.000
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -13.919822         2.572790           -5.410           0.000
# L1.temperature         0.795675         0.098496            8.078           0.000
# L1.rainfall            0.016768         0.011767            1.425           0.154
# L1.wind_speed          0.620545         0.014093           44.032           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.361675    0.365403
# rainfall         -0.361675  1.000000   -0.167999
# wind_speed        0.365403 -0.167999    1.000000
#
#
#
# Saved VAR model to trained_var_models\8_var_model.pkl
#
# Training VAR model for location: 9
# Dropped 'precipitation' due to perfect correlation with 'rainfall'.
# Variance per variable:
# temperature     2.365828
# rainfall       79.126269
# wind_speed     60.913425
# dtype: float64
# Correlation matrix:
#              temperature  rainfall  wind_speed
# temperature     1.000000 -0.305957    0.318994
# rainfall       -0.305957  1.000000   -0.025381
# wind_speed      0.318994 -0.025381    1.000000
# Fitted VAR model with lag 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Jul, 2025
# Time:                     10:49:14
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.62981
# Nobs:                     3690.00    HQIC:                   7.61680
# Log likelihood:          -29735.4    FPE:                    2017.48
# AIC:                      7.60961    Det(Omega_mle):         2010.93
# --------------------------------------------------------------------
# Results for equation temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  6.413675         0.316433           20.269           0.000
# L1.temperature         0.768556         0.011841           64.909           0.000
# L1.rainfall            0.003078         0.001941            1.586           0.113
# L1.wind_speed         -0.000431         0.002222           -0.194           0.846
# =================================================================================
#
# Results for equation rainfall
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  5.564584         2.673962            2.081           0.037
# L1.temperature        -0.064901         0.100057           -0.649           0.517
# L1.rainfall            0.317119         0.016403           19.333           0.000
# L1.wind_speed         -0.059946         0.018780           -3.192           0.001
# =================================================================================
#
# Results for equation wind_speed
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                -11.144930         1.840585           -6.055           0.000
# L1.temperature         0.771402         0.068873           11.200           0.000
# L1.rainfall           -0.009321         0.011291           -0.826           0.409
# L1.wind_speed          0.605865         0.012927           46.868           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                temperature  rainfall  wind_speed
# temperature       1.000000 -0.353106    0.112448
# rainfall         -0.353106  1.000000    0.051319
# wind_speed        0.112448  0.051319    1.000000
#
#
#
# Saved VAR model to trained_var_models\9_var_model.pkl
