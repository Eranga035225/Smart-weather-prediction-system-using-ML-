# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
# Load the cleaned dataset
df = pd.read_csv('./cleaned_weather_data.csv', index_col=0, parse_dates=True)

# %%
# Function to perform ADF Test
def check_adf(series, name):
    result = adfuller(series.dropna(), autolag='AIC')
    print(f"ADF Test for {name}:")
    print(f"  ADF Statistic  : {result[0]:.4f}")
    print(f"  p-value        : {result[1]:.4f}")
    print(f"  Stationary     : {'Yes' if result[1] < 0.05 else 'No'}")
    print("-" * 40)
    return result[1] < 0.05  # True if stationary

# %%
df.head()
# Out:
#            location  temperature  rainfall  wind_speed  precipitation
# date
# 2010-01-01   Ampara         25.6       0.0        21.7            0.0
# 2010-01-02   Ampara         25.8       1.1        21.1            1.1
# 2010-01-03   Ampara         24.9       1.5        16.4            1.5
# 2010-01-04   Ampara         24.9       0.0        19.2            0.0
# 2010-01-05   Ampara         24.3       0.0        18.4            0.0

# %%
numeric_cols = ['rainfall', 'precipitation', 'temperature', 'wind_speed']

stationary_flags = {}
for col in numeric_cols:
    stationary_flags[col] = check_adf(df[col], col)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 5
#       3 stationary_flags = {}
#       4 for col in numeric_cols:
# ----> 5     stationary_flags[col] = check_adf(df[col], col)
#
# Cell In[22], line 3, in check_adf(series, name)
#       2 def check_adf(series, name):
# ----> 3     result = adfuller(series.dropna(), autolag='AIC')
#       4     print(f"ADF Test for {name}:")
#       5     print(f"  ADF Statistic  : {result[0]:.4f}")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\stattools.py:326, in adfuller(x, maxlag, regression, autolag, store, regresults)
#     320 # 1 for level
#     321 # search for lag length with smallest information criteria
#     322 # Note: use the same number of observations to have comparable IC
#     323 # aic and bic: smaller is better
#     325 if not regresults:
# --> 326     icbest, bestlag = _autolag(
#     327         OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     328     )
#     329 else:
#     330     icbest, bestlag, alres = _autolag(
#     331         OLS,
#     332         xdshort,
#    (...)    337         regresults=regresults,
#     338     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\stattools.py:133, in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#     131 for lag in range(startlag, startlag + maxlag + 1):
#     132     mod_instance = mod(endog, exog[:, :lag], *modargs)
# --> 133     results[lag] = mod_instance.fit()
#     135 if method == "aic":
#     136     icbest, bestlag = min((v.aic, k) for k, v in results.items())
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\regression\linear_model.py:333, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     328 if method == "pinv":
#     329     if not (hasattr(self, 'pinv_wexog') and
#     330             hasattr(self, 'normalized_cov_params') and
#     331             hasattr(self, 'rank')):
# --> 333         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     334         self.normalized_cov_params = np.dot(
#     335             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     337         # Cache these singular values for use later.
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tools\tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\linalg\_linalg.py:1862, in svd(a, full_matrices, compute_uv, hermitian)
#    1858 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1859 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1860               invalid='call', over='ignore', divide='ignore',
#    1861               under='ignore'):
# -> 1862     u, s, vh = gufunc(a, signature=signature)
#    1863 u = u.astype(result_t, copy=False)
#    1864 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
# Step 2: Apply differencing only to non-stationary columns
df_diff = df.copy(deep=True)
for col, is_stationary in stationary_flags.items():
    if not is_stationary:
        df_diff[col] = df_diff[col].diff()
    else:
        # Keep original data if already stationary
        df_diff[col] = df[col]

# %%
# Step 3: Drop rows with NaN introduced by differencing
df_diff.dropna(inplace=True)

# %%
# Step 4: Plot original vs differenced data (only numeric columns)
fig, axs = plt.subplots(nrows=len(numeric_cols), ncols=2, figsize=(14, 4 * len(numeric_cols)))
for i, col in enumerate(numeric_cols):
    axs[i, 0].plot(df[col], label='Original')
    axs[i, 0].set_title(f'{col} (Original)')
    axs[i, 0].legend()

    axs[i, 1].plot(df_diff[col], label='Differenced' if not stationary_flags[col] else 'Original', color='orange')
    axs[i, 1].set_title(f'{col} (Differenced)' if not stationary_flags[col] else f'{col} (Original)')
    axs[i, 1].legend()

plt.tight_layout()
plt.show()

# %%
# Step 5: Save the stationarized dataset
df_diff.to_csv('weather_data_stationary.csv')
print("✅ Stationarized dataset saved to 'weather_data_stationary.csv'")
# Out:
# ✅ Stationarized dataset saved to 'weather_data_stationary.csv'

# %%
# Optional: Summary of what was differenced
print("\nSummary:")
print("Stationary columns:", [k for k, v in stationary_flags.items() if v])
print("Differenced columns:", [k for k, v in stationary_flags.items() if not v])
# Out:
# Summary:
# Stationary columns: ['rainfall', 'precipitation', 'temperature', 'wind_speed']
# Differenced columns: []
